-- %% [markdown]
-- # Make Stacked Denoising Autoencoder

-- %%
-- Out:
-- 1
-- 3
-- 5
-- 7
-- 9

-- %%
require 'torch'
-- Out:
-- {
--   deserialize : function: 0x0771c078
--   cat : function: 0x077045d8
--   cdata : function: 0x0770e160
--   newmetatable : function: 0x07704820
--   atan2 : function: 0x077052d0
--   random : function: 0x07704600
--   zero : function: 0x07703c10
--   logNormal : function: 0x07705410
--   totable : function: 0x07712578
--   getnumcores : function: 0x077046a0
--   cross : function: 0x07704448
--   deserializeFromStorage : function: 0x0771c058
--   inverse : function: 0x07705528
--   le : function: 0x07703fa8
--   isTypeOf : function: 0x07704ce8
--   min : function: 0x076ec840
--   prod : function: 0x076ec818
--   ger : function: 0x076ec688
--   eq : function: 0x07703ff8
--   addmm : function: 0x076ec6d8
--   ByteTensor : table: 0x07389788
--   Timer : table: 0x076e9648
--   addmv : function: 0x076ec6b0
--   match : function: 0x07703da0
--   xcorr2 : function: 0x07703ee0
--   DiskFile : table: 0x076ea6a0
--   bernoulli : function: 0x07703e40
--   MemoryFile : table: 0x076eed40
-- ...

-- %%
shuffle = torch.randperm(10)

-- %%
shuffle
-- Out:
--   3
--   4
--   9
--   6
--   7
--  10
--   8
--   1
--   2
--   5
-- [torch.DoubleTensor of size 10]
